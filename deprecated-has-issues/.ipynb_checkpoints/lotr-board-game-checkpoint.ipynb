# %%
import numpy as np
from numpy import array as arr
from numpy import random as choose
from math import ceil as ceil
from recordclass import recordclass, RecordClass

# %%
class Cut ( RecordClass ):
    name: str
    tiles: (int, int)
    

class Player ( RecordClass ):
    name: str
    tile: int
    ring: bool
    vector: int
    good: bool
    is_chasing: str

# %%
# int, List Player -> Dict

# int -> Dict {int: List str}
def empty_board ( board_size ):

    if board_size == 1:
        return {0: []}
    else:
        board = empty_board ( board_size - 1 )
        board[board_size - 1] = []
        return board

# int, List Cut --> Dict {int: List str}
def generate_board ( board_size, all_cuts ):
    
    board =  empty_board ( board_size )

    # List Cut -> None
    def place_cuts ( cuts ):
        this_cut = cuts[0]
        one_tile, other_tile = this_cut.tiles
        board[one_tile].append ( this_cut.name )
        board[other_tile].append ( this_cut.name )
        if len ( cuts ) > 1:
            place_cuts ( cuts[1:] )

    place_cuts ( all_cuts )

    return board

# Dict, List Player -> Dict {int: List str}
def put_players_on_board ( board, all_players ):

    # List Player -> None
    def place_players ( players ):
        this_player = players[0]
        board[this_player.tile].append ( this_player.name )
        if len (players) > 1:
            place_players ( players[1:] )

    place_players ( all_players )
    
    return board

# List str, List str, List, str, int -> List Cut
def generate_cuts ( names_long, names_med, names_short, board_size ):

    # float, int, int -> List int
    def get_cut_lengths ( min_length, max_add, num ):
        cut_length_mins = [(int(min_length))] * num
        cut_length_adds = list ( map ( choose.randint , [max_add] * num ))
        return  list ( arr ( cut_length_mins ) + arr ( cut_length_adds ) )

    long_cut_lengths =  get_cut_lengths ( board_size / 3, 20, len ( names_long ) )
    med_cut_lengths =  get_cut_lengths ( board_size / 6, 10, len ( names_med ) )
    short_cut_lengths =  get_cut_lengths ( board_size / 20, 5, len ( names_short ) )
    all_cut_lengths = long_cut_lengths + med_cut_lengths + short_cut_lengths

    all_cut_names = names_long + names_med + names_short

    # str, int, List int -> Cut
    def create_one_cut ( naam, length, choices ):
        ind = choose.randint ( len (choices) )
        one_end = choices[ind]
        other_endA = one_end - length
        other_endB = one_end + length
        if other_endA in choices:
            return Cut ( name = naam, tiles = ( other_endA, one_end ) )
        elif other_endB in choices:
            return Cut ( name = naam, tiles = ( one_end, other_endB ) )
        else: 
            new_choices = np.delete ( choices, ind )
            return create_one_cut ( naam, length, new_choices )

    # Could change create_all_cuts (...) to output None and just recursively update an 
    # initially empty list of cuts like above with board but wanted to change things up. 
    # Need to look up later if there is some advantage to one method over the other

    # List Cut, List str, List int, List int -> List Cut
    def create_all_cuts ( cuts, cut_names, cut_lengths, tiles ):
        new_cut = create_one_cut ( cut_names[0], cut_lengths[0], tiles )
        loc_one = np.where ( tiles == new_cut.tiles[0] )[0]
        loc_other = np.where ( tiles == new_cut.tiles[1] )[0]
        remaining_tiles = np.delete ( tiles, [loc_one, loc_other] )
        cuts.append ( new_cut )
        if len ( cut_names ) > 1:
            create_all_cuts ( cuts, cut_names[1:], cut_lengths[1:], remaining_tiles )
        return cuts
    
    all_tiles = np.arange ( board_size )[1:-1] 
    all_cuts = create_all_cuts ( [], all_cut_names, all_cut_lengths, all_tiles )
    
    return all_cuts

# int, int -> List Player
def generate_players ( board_size, num_players ):
    num_good_players = ceil ( num_players / 2 )

    # str -> Player
    create_good_player = lambda naam: Player ( name = naam, good = True, ring = False, tile = 0, vector = 1, is_chasing = None)

    # str -> Player
    create_evil_player = lambda naam: Player ( name = naam, good = False, ring = False, tile = board_size - 1, vector = -1, is_chasing = None)

    # List Player -> List Player
    def assign_ring_holder ( players ): 
        chosen_one = choose.randint( num_good_players )
        players[chosen_one].ring = True

    # List Player
    def create_all_players ():
        possible_good_players = ['Frodo', 'Sam', 'Gandalf']
        possible_evil_players = ['Sauron', 'Witch King', 'Mordu']

        good_player_names = possible_good_players[: num_good_players ]
        evil_player_names = possible_evil_players[: ( num_players - num_good_players ) ]
        good_players = list ( map ( create_good_player, good_player_names ))
        evil_players = list ( map ( create_evil_player, evil_player_names ))
        return good_players + evil_players

    players = create_all_players ()
    assign_ring_holder ( players )
    
    return players

# int, int -> List Player, Dict
def initialize_board ( board_size, num_players ):

    ### CUTS
    cuts = generate_cuts ( ['L1', 'L2', 'L3'], ['M1', 'M2', 'M3', 'M4', 'M5'], ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7'], board_size )

    ### BOARD
    board =  generate_board ( board_size, cuts )
    
    return cuts, board

def initialize_players ( board_size, num_players):

    ### PLAYERS
    players = generate_players ( board_size, num_players )

    return players

# %%
class GameState ( RecordClass ):
    finished: bool
    winner: bool # True if GOOD, False if EVIL
    num_turns: int
    players: list
    whose_turn: int

class GameStatistics ( RecordClass ):
    num_games: int
    num_finished: int
    num_good_won: int
    winners: list
    turns: list

# %%
# List Cut -> List Int
def collapse_cuts ( all_cuts ):

    collapsed = []

    def collapse ( list_of_cuts ):
        cut = list_of_cuts[0] 
        collapsed.append ( cut.tiles[0] )
        collapsed.append ( cut.tiles[1] )
        if len ( list_of_cuts ) > 1:
            collapse ( list_of_cuts[1:] )

    collapse ( all_cuts )
    return np.array ( collapsed )

# int, List Cut -> int
def get_other_cut_end ( ends, this_end ):
    ind = np.where ( ends == this_end )[0]
    if ind % 2 == 1:
        return ends [ind - 1][0]
    else:
        return ends [ind + 1][0]


# available variables: board, cuts, players, cut_ends

# Player -> int
get_player_loc = lambda player: player.tile
get_player_name = lambda player: player.name
get_player_goodness = lambda player: player.good
player_has_ring = lambda player: player.ring

# int -> GameState
def play_game ( moves_left, init_players, cut_ends, die_faces ):

    num_players = len (init_players)
    num_good_players = ceil ( num_players / 2 )
    max_tile = init_players[-1].tile 

    # None -> int
    def roll_dice ():
        return choose.randint ( die_faces )

    # GameState -> GameState
    def play_turn ( state ):
        
        all_players = state.players
        all_player_locs = np.array ( list ( map ( get_player_loc, all_players ) ) )
        
        this_turn = ( state.whose_turn + 1 ) % (num_players)
        this_player = all_players[this_turn]
        this_loc = this_player.tile

        
        '''
        if there's only one good player and they've crossed you, obviously start chasing them

        if you've been crossed by all good players, you should start chasing one of them

        if you've been crossed by a subset of good players, 
        you will chase one of them with probability num_crossers / num_good_players
        '''
        # None -> None (updates this player's chasing state and vector)
        def maybe_chase ( ):

            # Player -> List Player
            def good_crossers ( player ):
                
                good_players = all_players[:num_good_players]
                good_locs = np.array ( list ( map ( get_player_loc, good_players ) ) )
                crosser_inds = np.where ( good_locs > this_player.tile )[0]
                
                return [good_players[ind] for ind in crosser_inds]

            crossers = good_crossers ( this_player )
            num_good_crossers = len ( crossers )
            
            if num_good_crossers > 0: 
                
                pick = choose.randint ( num_good_players )
                
                if pick < num_good_crossers:
                    this_player.is_chasing = crossers[pick].name
                    this_player.vector = 1


        '''
        if a bad player is not chasing anyone currently, they have the option to chase a good player who's passed them earlier
        '''
        if not this_player.good and this_player.is_chasing == None:
            maybe_chase ()


        '''
        don't fall off the board!
        '''
        # int -> int (don't fall off the board!)
        def stay_on_board ( tile ):
            if tile > max_tile:
                return max_tile
            elif tile < 0:
                return 0
            else:
                return tile

        '''
        roll a dice, move forward, take a cut if you land on a cut end
        '''
        # None -> None
        def update_location ():
            
            steps = roll_dice ()
            maybe_new_loc = stay_on_board ( this_loc + this_player.vector * steps )
    
            if maybe_new_loc in cut_ends:
                take_cut = choose.randint ( 2 )
                if take_cut:
                    new_loc = get_other_cut_end ( cut_ends, maybe_new_loc )
                else:
                    new_loc = maybe_new_loc
            else:
                new_loc = maybe_new_loc
            
            this_player.tile = new_loc

            
        update_location ()

        
        '''
        query properties of other players on the tile this player just landed on
        '''
        cohab_inds = np.where ( all_player_locs == this_player.tile )[0]
        num_cohabitors = len ( cohab_inds )
        if num_cohabitors > 1:
            
            cohabitors = [all_players[ind] for ind in cohab_inds] # drasted for loops here, list.map is leading to dumb errors and I'm tired
            cohabitor_names = list ( map ( get_player_name, cohabitors ) )
            
            cohabitor_goods = list ( map ( get_player_goodness, cohabitors ) )
            all_cohabitors_good = all ( cohabitor_goods )
            
            is_ring_here = np.array ( list ( map ( player_has_ring, cohabitors ) ) )
            ring_location = np.where ( is_ring_here )[0]
            ring_bearer_here = len ( ring_location )
            
            if ring_bearer_here > 0:
                ring_bearer = all_players[ring_location[0]]
            
        else:
            ring_bearer_here = 0


        
        # None -> None (change direction to shire, stop chasing)
        def to_shire_and_stop_chasing ():
            this_player.vector = -1
            this_player.is_chasing = None


        '''
        ring bearer maybe swaps the ring with one of those other good players, unbeknownst to bad players
        50% chance of swap, other 50% equally divided amongst potential swapees
        '''
        def maybe_give_away_ring ():
            cohab_inds_except_this_one = np.delete ( cohab_inds, np.where ( cohab_inds == this_turn ) )
            num_others = len ( cohab_inds_except_this_one )
            maybe_swap = choose.randint ( 2 * num_others )
            
            if maybe_swap < num_others:
                ring_swapee_ind = cohab_inds_except_this_one[maybe_swap]
                ring_swapee = all_players[ring_swapee_ind]
                this_player.ring = False
                ring_swapee.ring = True

        '''
        good non-ring bearer maybe takes the ring, unbeknownst to bad players
        50% chance of take
        '''
        def maybe_take_ring ():
            take = choose.randint ( 2 )
            if take:
                ring_bearer.ring = False
                this_player.ring = True
            
        '''
        if the ring bearer reaches Mordor
        '''
        
        if this_player.ring and this_player.tile == max_tile:
            who_won = True
            gameover = True
            
        elif this_player.ring and num_cohabitors > 1:
            
            if not all_cohabitors_good:
                '''
                if the ring bearer stumbles upon a bad player
                '''
                who_won = False
                gameover = True
                
            else:
                '''
                if the ring bearer stumbles upon other good players
                '''
                who_won = None
                gameover = False
                maybe_give_away_ring ()

        
        elif this_player.good and ring_bearer_here > 0:
            '''
            if this good player stumbles upon the ring bearer
            '''
            who_won = None
            gameover = False
            maybe_take_ring ()
        
        
        elif not this_player.good and ( ( this_player.tile == max_tile ) or ( num_cohabitors > 1 and ring_bearer_here == 0 and this_player.is_chasing in cohabitor_names ) ): 
            '''
            if this bad player is on the last tile
            or happened to have landed on the tile of who they were chasing but found out they didn't have the ring after all,
            then they stop chasing that player and turn towards shire
            -- note that this can get reversed immediately if on their next turn they chase another good crosser
            -- not also that they don't pick a new good player to chase until the next round
            '''
            who_won = None
            gameover = False
            to_shire_and_stop_chasing ()

        elif not this_player.good and ring_bearer_here > 0:
            '''
            if this bad player caught or stumbled upon the ring bearer
            '''
            who_won = False
            gameover = True

        else:
            '''
            if none of those critical situations happen, just proceed
            '''
            who_won = None
            gameover = False

        new_state = GameState (whose_turn = this_turn, num_turns = state.num_turns + 1, players = all_players, winner = who_won, finished = gameover)
        return new_state

    if moves_left == 0:
        
        initial_state  = GameState (finished = False, winner = None, num_turns = 0, players = init_players, whose_turn = -1)
        return initial_state

    else:
        
        last_state = play_game ( moves_left - 1, init_players, cut_ends, die_faces )

        if not last_state.finished:
            return play_turn ( last_state )
        else:
            return last_state



# GameStatistics, GameState -> GameStatistics
def update_stats ( current_stats, new_result ):
    
    current_stats.num_games += 1
    current_stats.turns.append ( new_result.num_turns )
    
    if new_result.finished:
        current_stats.num_finished += 1

    if new_result.winner:
        current_stats.num_good_won += 1
        current_stats.winners.append ( True )

    else:
        current_stats.winners.append ( False )
            


# Ugh wanted to use this recursive function but frikkin' python exceeds max recursion depth if my num_games > 1000
# I suppose python is rightfully afraid of stack overflow
# So I guess I'll do a damn for loop, in the function after this...

# int -> GameStatistics
def play_many_games_recursively ( num_games, max_moves ):

    game_stats = GameStatistics ( num_games = 0, num_finished = 0, num_good_won = 0, turns = [], winners = [] )

    size = 70
    numplay = 6

    cuts, board = initialize_board ( size, numplay )
    print ( board )
    print ()
    cut_ends = collapse_cuts ( cuts )

    # int -> None
    def play ( games_left ):

        init_players = initialize_players ( size, numplay )
        result = play_game ( max_moves, init_players )
        update_stats ( game_stats, result )
        
        if games_left > 1:
            play ( games_left - 1 )

    play ( num_games )
    
    return game_stats



# int -> GameStatistics
def play_many_games ( num_games, *params ):

    moves_per_player, size, die_faces, numplay = params
    max_moves = moves_per_player * numplay

    game_stats = GameStatistics ( num_games = 0, num_finished = 0, num_good_won = 0, turns = [], winners = [] )

    cuts, board = initialize_board ( size, numplay )
    # print ( board )
    # print ()
    cut_ends = collapse_cuts ( cuts )

    # int -> None
    def play ():

        init_players = initialize_players ( size, numplay )
        result = play_game ( max_moves, init_players, cut_ends, die_faces )
        # print ( result )
        # print ()
        update_stats ( game_stats, result )

    for i in range ( num_games ):
        play ()
    
    return cuts, board, game_stats

# bs = 79
# df = 4
# nump = 2
# # moves_per_player, size, numplay, die_faces
# these_params = [25, bs, df, nump]
# these_cuts, this_board, all_game_stats = play_many_games (10000, *these_params)
# print ( np.mean(np.array(all_game_stats.turns)) )
# print ( 'good win fraction', all_game_stats.num_good_won / all_game_stats.num_finished )
# print ( 'finish fraction', all_game_stats.num_finished / all_game_stats.num_games )



# test boards

# size of board: 70 - 90 in increments of 1
# die rolls: 4,5,6
# for param set in prod(params)
# generate 100 boards for each parameter set

# save board and parameter set for each test
# save also board and parameter set for special set of "preferred_games"

# test for 2,3,4,5,6 players
# test 10000 games for each board, player set
# goal: find board which gives 40-60% good_won/num_finished for all player values, and 80% games < 20*numplayers and 90% of games < 30*numplayers

# %%
from itertools import product
from tqdm import tqdm

get_good_win_fraction = lambda stats: stats.num_good_won / stats.num_finished
get_finish_fraction = lambda stats: stats.num_finished / stats.num_games

num_boardsizes = 11
num_diefaces = 3
num_numplayers = 5
boardsizes_to_test = np.linspace ( 70, 80, num_boardsizes )
die_faces_to_test = np.linspace ( 4, 6, num_diefaces )
numplayers_to_test = np.linspace ( 2, 6, num_numplayers )
numboards_to_test = 100

total_num_games = num_boardsizes * num_diefaces * num_numplayers * numboards_to_test

cutoff_turns_per_player = 25
min_frac_won = 0.39
max_frac_won = 0.61
desired_frac_finished_in_reasonable_time = 0.4



all_games = []
preferred_games_and_player_numbers = []
preferred_games = []
i = 1

pbar = tqdm ( total = total_num_games )

for boardsize, dierolls in product(boardsizes_to_test, die_faces_to_test):

    good_for_all_player_numbers = True

    for b in range ( numboards_to_test ):
    
        for numplayers in numplayers_to_test:
    
            # print ('testing boardgame number ' + str(i) + ' out of ' + str(total))
    
            these_params = [cutoff_turns_per_player, int(boardsize), int(dierolls), int(numplayers)]
            these_cuts, this_board, these_game_stats = play_many_games (1000, *these_params)
            all_games.append ( (numplayers, dierolls, this_board, these_game_stats) )
            
            good_win_fraction = get_good_win_fraction ( these_game_stats )
            finish_fraction = get_finish_fraction ( these_game_stats )
    
            pbar.update ( 1 )
            
            if good_win_fraction < min_frac_won or good_win_fraction > max_frac_won or finish_fraction > desired_frac_finished_in_reasonable_time:
                good_for_all_player_numbers = False
            else:
                preferred_games_and_player_numbers.append ( (numplayers, dierolls, this_board, these_game_stats) )
    
        if good_for_all_player_numbers:
            print ('found a preferred boardgame!')
            for game in preferred_games_and_player_numbers[-5:]:
                preferred_games.append ( game )

pbar.close ()


for game in preferred_games:
    dierolls, this_board, these_game_stats = game
    
    print ('die rolls', dierolls)
    print()

    print ('board', this_board)
    print()

    print ('good win fraction', get_good_win_fraction ( these_game_stats ) )
    print()

    print ('finish fraction', get_finish_fraction ( these_game_stats ) )
    print()
# Out:
# testing boardgame number 1 out of 16500
# testing boardgame number 2 out of 16500
# testing boardgame number 3 out of 16500
# testing boardgame number 4 out of 16500
# testing boardgame number 5 out of 16500
# testing boardgame number 6 out of 16500
# testing boardgame number 7 out of 16500
# testing boardgame number 8 out of 16500
# testing boardgame number 9 out of 16500
# testing boardgame number 10 out of 16500
# testing boardgame number 11 out of 16500
# testing boardgame number 12 out of 16500
# testing boardgame number 13 out of 16500
# testing boardgame number 14 out of 16500
# testing boardgame number 15 out of 16500
# testing boardgame number 16 out of 16500
# testing boardgame number 17 out of 16500
# testing boardgame number 18 out of 16500
# testing boardgame number 19 out of 16500
# testing boardgame number 20 out of 16500
# testing boardgame number 21 out of 16500
# testing boardgame number 22 out of 16500
# testing boardgame number 23 out of 16500
# testing boardgame number 24 out of 16500
# testing boardgame number 25 out of 16500
# testing boardgame number 26 out of 16500
# testing boardgame number 27 out of 16500
# testing boardgame number 28 out of 16500
# testing boardgame number 29 out of 16500
# testing boardgame number 30 out of 16500
# testing boardgame number 31 out of 16500
# testing boardgame number 32 out of 16500
# testing boardgame number 33 out of 16500
# testing boardgame number 34 out of 16500
# testing boardgame number 35 out of 16500
# testing boardgame number 36 out of 16500
# testing boardgame number 37 out of 16500
# testing boardgame number 38 out of 16500
# testing boardgame number 39 out of 16500
# testing boardgame number 40 out of 16500
# testing boardgame number 41 out of 16500
# testing boardgame number 42 out of 16500
# testing boardgame number 43 out of 16500
# testing boardgame number 44 out of 16500
# testing boardgame number 45 out of 16500
# testing boardgame number 46 out of 16500
# testing boardgame number 47 out of 16500
# testing boardgame number 48 out of 16500
# testing boardgame number 49 out of 16500
# testing boardgame number 50 out of 16500
# testing boardgame number 51 out of 16500
# testing boardgame number 52 out of 16500
# testing boardgame number 53 out of 16500
# testing boardgame number 54 out of 16500
# testing boardgame number 55 out of 16500
# testing boardgame number 56 out of 16500
# testing boardgame number 57 out of 16500
# testing boardgame number 58 out of 16500
# testing boardgame number 59 out of 16500
# testing boardgame number 60 out of 16500
# testing boardgame number 61 out of 16500
# testing boardgame number 62 out of 16500
# testing boardgame number 63 out of 16500
# testing boardgame number 64 out of 16500
# testing boardgame number 65 out of 16500
# testing boardgame number 66 out of 16500
# testing boardgame number 67 out of 16500
# testing boardgame number 68 out of 16500
# testing boardgame number 69 out of 16500
# testing boardgame number 70 out of 16500
# testing boardgame number 71 out of 16500
# testing boardgame number 72 out of 16500
# testing boardgame number 73 out of 16500
# testing boardgame number 74 out of 16500
# testing boardgame number 75 out of 16500
# testing boardgame number 76 out of 16500
# testing boardgame number 77 out of 16500
# testing boardgame number 78 out of 16500
# testing boardgame number 79 out of 16500
# testing boardgame number 80 out of 16500
# testing boardgame number 81 out of 16500
# testing boardgame number 82 out of 16500
# testing boardgame number 83 out of 16500
# testing boardgame number 84 out of 16500
# testing boardgame number 85 out of 16500
# testing boardgame number 86 out of 16500
# testing boardgame number 87 out of 16500
# testing boardgame number 88 out of 16500
# testing boardgame number 89 out of 16500
# testing boardgame number 90 out of 16500
# testing boardgame number 91 out of 16500
# testing boardgame number 92 out of 16500
# testing boardgame number 93 out of 16500
# testing boardgame number 94 out of 16500
# testing boardgame number 95 out of 16500
# testing boardgame number 96 out of 16500
# testing boardgame number 97 out of 16500
# testing boardgame number 98 out of 16500
# testing boardgame number 99 out of 16500
# testing boardgame number 100 out of 16500
# testing boardgame number 101 out of 16500
# testing boardgame number 102 out of 16500
# testing boardgame number 103 out of 16500
# testing boardgame number 104 out of 16500
# testing boardgame number 105 out of 16500
# testing boardgame number 106 out of 16500
# testing boardgame number 107 out of 16500
# testing boardgame number 108 out of 16500
# testing boardgame number 109 out of 16500
# testing boardgame number 110 out of 16500
# testing boardgame number 111 out of 16500
# testing boardgame number 112 out of 16500
# testing boardgame number 113 out of 16500
# testing boardgame number 114 out of 16500
# testing boardgame number 115 out of 16500
# testing boardgame number 116 out of 16500
# testing boardgame number 117 out of 16500
# testing boardgame number 118 out of 16500
# testing boardgame number 119 out of 16500
# testing boardgame number 120 out of 16500
# testing boardgame number 121 out of 16500
# testing boardgame number 122 out of 16500
# testing boardgame number 123 out of 16500
# testing boardgame number 124 out of 16500
# testing boardgame number 125 out of 16500
# testing boardgame number 126 out of 16500
# testing boardgame number 127 out of 16500
# testing boardgame number 128 out of 16500
# testing boardgame number 129 out of 16500
# testing boardgame number 130 out of 16500
# testing boardgame number 131 out of 16500
# testing boardgame number 132 out of 16500
# testing boardgame number 133 out of 16500
# testing boardgame number 134 out of 16500
# testing boardgame number 135 out of 16500
# testing boardgame number 136 out of 16500
# testing boardgame number 137 out of 16500
# testing boardgame number 138 out of 16500
# testing boardgame number 139 out of 16500
# testing boardgame number 140 out of 16500
# testing boardgame number 141 out of 16500
# testing boardgame number 142 out of 16500
# testing boardgame number 143 out of 16500
# testing boardgame number 144 out of 16500
# testing boardgame number 145 out of 16500
# testing boardgame number 146 out of 16500
# testing boardgame number 147 out of 16500
# testing boardgame number 148 out of 16500
# testing boardgame number 149 out of 16500
# testing boardgame number 150 out of 16500
# testing boardgame number 151 out of 16500
# testing boardgame number 152 out of 16500
# testing boardgame number 153 out of 16500
# testing boardgame number 154 out of 16500
# testing boardgame number 155 out of 16500
# testing boardgame number 156 out of 16500
# testing boardgame number 157 out of 16500
# testing boardgame number 158 out of 16500
# testing boardgame number 159 out of 16500
# testing boardgame number 160 out of 16500
# testing boardgame number 161 out of 16500
# testing boardgame number 162 out of 16500
# testing boardgame number 163 out of 16500
# testing boardgame number 164 out of 16500
# testing boardgame number 165 out of 16500
# testing boardgame number 166 out of 16500
# testing boardgame number 167 out of 16500
# testing boardgame number 168 out of 16500
# testing boardgame number 169 out of 16500
# testing boardgame number 170 out of 16500
# testing boardgame number 171 out of 16500
# testing boardgame number 172 out of 16500
# testing boardgame number 173 out of 16500
# testing boardgame number 174 out of 16500
# testing boardgame number 175 out of 16500
# testing boardgame number 176 out of 16500
# testing boardgame number 177 out of 16500
# testing boardgame number 178 out of 16500
# testing boardgame number 179 out of 16500
# testing boardgame number 180 out of 16500
# testing boardgame number 181 out of 16500
# testing boardgame number 182 out of 16500
# testing boardgame number 183 out of 16500
# testing boardgame number 184 out of 16500
# testing boardgame number 185 out of 16500
# testing boardgame number 186 out of 16500
# testing boardgame number 187 out of 16500
# testing boardgame number 188 out of 16500
# testing boardgame number 189 out of 16500
# testing boardgame number 190 out of 16500
# testing boardgame number 191 out of 16500
# testing boardgame number 192 out of 16500
# testing boardgame number 193 out of 16500
# testing boardgame number 194 out of 16500
# testing boardgame number 195 out of 16500
# testing boardgame number 196 out of 16500
# testing boardgame number 197 out of 16500
# testing boardgame number 198 out of 16500
# testing boardgame number 199 out of 16500
# testing boardgame number 200 out of 16500
# testing boardgame number 201 out of 16500
# testing boardgame number 202 out of 16500
# testing boardgame number 203 out of 16500
# testing boardgame number 204 out of 16500
# testing boardgame number 205 out of 16500
# testing boardgame number 206 out of 16500
# testing boardgame number 207 out of 16500
# testing boardgame number 208 out of 16500
# testing boardgame number 209 out of 16500
# testing boardgame number 210 out of 16500
# testing boardgame number 211 out of 16500
# testing boardgame number 212 out of 16500
# testing boardgame number 213 out of 16500
# testing boardgame number 214 out of 16500
# testing boardgame number 215 out of 16500
# testing boardgame number 216 out of 16500
# testing boardgame number 217 out of 16500
# testing boardgame number 218 out of 16500
# testing boardgame number 219 out of 16500
# testing boardgame number 220 out of 16500
# testing boardgame number 221 out of 16500
# testing boardgame number 222 out of 16500
# testing boardgame number 223 out of 16500
# testing boardgame number 224 out of 16500
# testing boardgame number 225 out of 16500
# testing boardgame number 226 out of 16500
# testing boardgame number 227 out of 16500
# testing boardgame number 228 out of 16500
# testing boardgame number 229 out of 16500
# testing boardgame number 230 out of 16500
# testing boardgame number 231 out of 16500
# testing boardgame number 232 out of 16500
# testing boardgame number 233 out of 16500
# testing boardgame number 234 out of 16500
# testing boardgame number 235 out of 16500
# testing boardgame number 236 out of 16500
# testing boardgame number 237 out of 16500
# testing boardgame number 238 out of 16500
# testing boardgame number 239 out of 16500
# testing boardgame number 240 out of 16500
# testing boardgame number 241 out of 16500
# testing boardgame number 242 out of 16500
# testing boardgame number 243 out of 16500
# testing boardgame number 244 out of 16500
# testing boardgame number 245 out of 16500
# testing boardgame number 246 out of 16500
# testing boardgame number 247 out of 16500
# testing boardgame number 248 out of 16500
# testing boardgame number 249 out of 16500
# testing boardgame number 250 out of 16500
# testing boardgame number 251 out of 16500
# testing boardgame number 252 out of 16500
# testing boardgame number 253 out of 16500
# testing boardgame number 254 out of 16500
# testing boardgame number 255 out of 16500
# testing boardgame number 256 out of 16500
# testing boardgame number 257 out of 16500
# testing boardgame number 258 out of 16500
# testing boardgame number 259 out of 16500
# testing boardgame number 260 out of 16500
# testing boardgame number 261 out of 16500
# testing boardgame number 262 out of 16500
# testing boardgame number 263 out of 16500
# testing boardgame number 264 out of 16500
# testing boardgame number 265 out of 16500
# testing boardgame number 266 out of 16500
# testing boardgame number 267 out of 16500
# testing boardgame number 268 out of 16500
# testing boardgame number 269 out of 16500
# testing boardgame number 270 out of 16500
# testing boardgame number 271 out of 16500
# testing boardgame number 272 out of 16500
# testing boardgame number 273 out of 16500
# testing boardgame number 274 out of 16500
# testing boardgame number 275 out of 16500
# testing boardgame number 276 out of 16500
# testing boardgame number 277 out of 16500
# testing boardgame number 278 out of 16500
# testing boardgame number 279 out of 16500
# testing boardgame number 280 out of 16500
# testing boardgame number 281 out of 16500
# testing boardgame number 282 out of 16500
# testing boardgame number 283 out of 16500
# testing boardgame number 284 out of 16500
# testing boardgame number 285 out of 16500
# testing boardgame number 286 out of 16500
# testing boardgame number 287 out of 16500
# testing boardgame number 288 out of 16500
# testing boardgame number 289 out of 16500
# testing boardgame number 290 out of 16500
# testing boardgame number 291 out of 16500
# testing boardgame number 292 out of 16500
# testing boardgame number 293 out of 16500
# testing boardgame number 294 out of 16500
# testing boardgame number 295 out of 16500
# testing boardgame number 296 out of 16500
# testing boardgame number 297 out of 16500
# testing boardgame number 298 out of 16500
# testing boardgame number 299 out of 16500
# testing boardgame number 300 out of 16500
# testing boardgame number 301 out of 16500
# testing boardgame number 302 out of 16500
# testing boardgame number 303 out of 16500
# testing boardgame number 304 out of 16500
# testing boardgame number 305 out of 16500
# testing boardgame number 306 out of 16500
# testing boardgame number 307 out of 16500
# testing boardgame number 308 out of 16500
# testing boardgame number 309 out of 16500
# testing boardgame number 310 out of 16500
# testing boardgame number 311 out of 16500
# testing boardgame number 312 out of 16500
# testing boardgame number 313 out of 16500
# testing boardgame number 314 out of 16500
# testing boardgame number 315 out of 16500
# testing boardgame number 316 out of 16500
# testing boardgame number 317 out of 16500
# testing boardgame number 318 out of 16500
# testing boardgame number 319 out of 16500
# testing boardgame number 320 out of 16500
# testing boardgame number 321 out of 16500
# testing boardgame number 322 out of 16500
# testing boardgame number 323 out of 16500
# testing boardgame number 324 out of 16500
# testing boardgame number 325 out of 16500
# testing boardgame number 326 out of 16500
# testing boardgame number 327 out of 16500
# testing boardgame number 328 out of 16500
# testing boardgame number 329 out of 16500
# testing boardgame number 330 out of 16500
# testing boardgame number 331 out of 16500
# testing boardgame number 332 out of 16500
# testing boardgame number 333 out of 16500
# testing boardgame number 334 out of 16500
# testing boardgame number 335 out of 16500
# testing boardgame number 336 out of 16500
# testing boardgame number 337 out of 16500
# testing boardgame number 338 out of 16500
# testing boardgame number 339 out of 16500
# testing boardgame number 340 out of 16500
# testing boardgame number 341 out of 16500
# testing boardgame number 342 out of 16500
# testing boardgame number 343 out of 16500
# testing boardgame number 344 out of 16500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 39
#      36 print ('testing boardgame number ' + str(i) + ' out of ' + str(total))
#      38 these_params = [cutoff_turns_per_player, int(boardsize), int(dierolls), int(numplayers)]
# ---> 39 these_cuts, this_board, these_game_stats = play_many_games (1000, *these_params)
#      40 all_games.append ( (numplayers, dierolls, this_board, these_game_stats) )
#      42 good_win_fraction = get_good_win_fraction ( these_game_stats )
#
# Cell In[9], line 340, in play_many_games(num_games, *params)
#     337     update_stats ( game_stats, result )
#     339 for i in range ( num_games ):
# --> 340     play ()
#     342 return cuts, board, game_stats
#
# Cell In[9], line 333, in play_many_games.<locals>.play()
#     331 def play ():
# --> 333     init_players = initialize_players ( size, numplay )
#     334     result = play_game ( max_moves, init_players, cut_ends, die_faces )
#     335     # print ( result )
#     336     # print ()
#
# Cell In[3], line 140, in initialize_players(board_size, num_players)
#     137 def initialize_players ( board_size, num_players):
#     138
#     139     ### PLAYERS
# --> 140     players = generate_players ( board_size, num_players )
#     142     return players
#
# Cell In[3], line 121, in generate_players(board_size, num_players)
#     118     evil_players = list ( map ( create_evil_player, evil_player_names ))
#     119     return good_players + evil_players
# --> 121 players = create_all_players ()
#     122 assign_ring_holder ( players )
#     124 return players
#
# KeyboardInterrupt:

# %%
                # if num_good_players == 1:
                #     '''
                #     if there's only one good player and they've crossed you, obviously start chasing them
                #     '''
                #     this_player.is_chasing = crossers[0].name
                #     this_player.vector = 1

                # elif num_good_crossers == num_good_players:
                #     '''
                #     if you've been crossed by all good players, you should start chasing one of them
                #         it's probably not super accurate to give equal chance of chasing to all of them
                #     '''
                #     pick = choose.randint ( num_good_crossers )
                #     this_player.is_chasing = crossers[pick].name
                #     this_player.vector = 1

                # else:
                #     '''
                #     if you've been crossed by a subset of good players, 
                #     you can chase one of them with probability num_crossers / num_good_players
                #     '''
                #     pick = choose.randint ( num_good_players )
                    
                #     if pick != num_good_crossers:
                #         this_player.is_chasing = crossers[pick].name
                #         this_player.vector = 1
